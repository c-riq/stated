# %%
import os
import re
import datetime

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import json

# %%
base_path = '/Users/c/Desktop/project/jupyter_20191230/data/wikidata/extract_org_urls/'

# %%
df = pd.read_csv(base_path + 'till_Q106411824.csv')

# %%
dfs = list()
for f in os.listdir(base_path):
    if not ('csv' in f):
        continue
    data = pd.read_csv(base_path + f)
    #data['file'] = f.stem
    dfs.append(data)

df = pd.concat(dfs, ignore_index=True)

# %%
df.type_id.value_counts()
# Out:
# Q4830453     92411
# Q3918        10629
# Q62078547      162
# Name: type_id, dtype: int64

# %%
df.plot.scatter(x="lon", y="lat", alpha=0.2, s=0.2)
# Out:
# <AxesSubplot:xlabel='lon', ylabel='lat'>

# %%
df.sort_values(by='employees',ascending=False)[['english_label','employees']]
# Out:
#                                   english_label  employees
# 48566                                     Billa  5555555.0
# 48520                                   Walmart  2500000.0
# 19208      China National Petroleum Corporation  1589508.0
# 81421           State Grid Corporation of China  1581000.0
# 40841                                    Amazon  1298000.0
# ...                                         ...        ...
# 103197           TherapeuticsMD (United States)        NaN
# 103198                 Tracoe Medical (Germany)        NaN
# 103199  Triad National Security (United States)        NaN
# 103200                 Tristel (United Kingdom)        NaN
# 103201                 Ulrich Medical (Germany)        NaN
#
# [103202 rows x 2 columns]

# %%
df
# Out:
#         Unnamed: 0          id   type_id  \
# 0                0    Q5941995     Q3918
# 1                1    Q5942230  Q4830453
# 2                2    Q5943259  Q4830453
# 3                3    Q5943971  Q4830453
# 4                4    Q5945524     Q3918
# ...            ...         ...       ...
# 103197        4995  Q106411808  Q4830453
# 103198        4996  Q106411815  Q4830453
# 103199        4997  Q106411817  Q4830453
# 103200        4998  Q106411823  Q4830453
# 103201        4999  Q106411824  Q4830453
#
#                                   english_label  \
# 0                 Hunan Agricultural University
# 1                                      Bank Day
# 2                                 Taiwan Mobile
# 3                              Hunt Oil Company
# 4                         Huntington University
# ...                                         ...
# 103197           TherapeuticsMD (United States)
# 103198                 Tracoe Medical (Germany)
# 103199  Triad National Security (United States)
# 103200                 Tristel (United Kingdom)
# 103201                 Ulrich Medical (Germany)
#
#                        official_website      lat        lon country_id  \
# 0              http://www.hunau.edu.cn/      NaN        NaN       Q148
# 1                  http://bank-day.org/      NaN        NaN    Q891723
# 2          http://www.taiwanmobile.com/      NaN        NaN       Q865
# 3               http://www.huntoil.com/  32.7875 -96.802222        Q30
# 4             http://www.huntington.edu      NaN        NaN        Q30
# ...                                 ...      ...        ...        ...
# 103197  https://www.therapeuticsmd.com/      NaN        NaN        Q30
# 103198          https://www.tracoe.com/      NaN        NaN       Q183
# 103199         https://www.triadns.org/      NaN        NaN        Q30
# 103200         https://www.tristel.com/      NaN        NaN       Q145
# 103201    https://www.ulrichmedical.de/      NaN        NaN       Q183
#
#        city_id  employees twitter_id twitter_name          crunchbase_id  \
# 0          NaN        NaN        NaN          NaN                    NaN
# 1        Q3616        NaN        NaN          NaN                    NaN
# 2         Q865        NaN        NaN          NaN                    NaN
# 3       Q16557        NaN        NaN          NaN                    NaN
# 4          NaN      304.0        NaN          NaN  huntington-university
# ...        ...        ...        ...          ...                    ...
# 103197  Q29422        NaN        NaN          NaN         therapeuticsmd
# 103198     NaN        NaN        NaN          NaN                    NaN
# 103199     NaN        NaN        NaN          NaN                    NaN
# 103200     NaN        NaN        NaN          NaN                    NaN
# 103201     NaN        NaN        NaN          NaN                    NaN
#
#                  facebook_id linkedin_id        grid_id
# 0                        NaN         NaN  grid.257160.7
# 1                        NaN         NaN            NaN
# 2               taiwanmobile         NaN            NaN
# 3                        NaN         NaN            NaN
# 4       huntingtonuniversity         NaN  grid.431789.0
# ...                      ...         ...            ...
# 103197                   NaN         NaN  grid.510109.c
# 103198                   NaN         NaN  grid.510119.d
# 103199                   NaN         NaN  grid.510120.7
# 103200                   NaN         NaN  grid.510128.f
# 103201                   NaN         NaN  grid.510130.6
#
# [103202 rows x 16 columns]

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql://sdf:sdf@localhost:5432/dev')
df.to_sql('wikidata_org_domains', engine)
# Out:
# 202
